# %%
import numpy as np
from matplotlib import pyplot as plt

Reading_One = np.load('./seti-breakthrough-listen/train/0/0242546174808dd.npy')
Reading_Two = np.load('./seti-breakthrough-listen/train/0/0a0ab532e0a74aa.npy')
Reading_Three = np.load('./seti-breakthrough-listen/train/0/0a0cf5f1c4dc03a.npy')
# plt.imshow(img_array, cmap='gray')
# plt.show()

CAD_One = Reading_One[0][0]
FIRST_SPECTROGRAM_One = Reading_One[1][0]
SECOND_SPECTROGRAM_One = Reading_One[2][0]

CAD_Two = Reading_Two[0][0]
FIRST_SPECTROGRAM_Two = Reading_Two[1][0]
SECOND_SPECTROGRAM_Two = Reading_Two[2][0]

CAD_Three = Reading_Three[0][0]
FIRST_SPECTROGRAM_Three = Reading_Three[1][0]
SECOND_SPECTROGRAM_Three = Reading_Three[2][0]

figure,axis = plt.subplots(1,3,figsize=(18,7))

axis[0].set_title("CADENCE")
axis[0].set_xlabel(CAD_One.shape)
axis[0].set_ylabel(CAD_One.size)
axis[0].plot(CAD_One,c="r")

axis[1].set_title("SPECTROGRAM")
axis[1].set_xlabel(FIRST_SPECTROGRAM_One.shape)
axis[1].set_ylabel(FIRST_SPECTROGRAM_One.size)
axis[1].plot(FIRST_SPECTROGRAM_One,c="r")

axis[2].set_title("SPECTROGRAM")
axis[2].set_xlabel(SECOND_SPECTROGRAM_One.shape)
axis[2].set_ylabel(SECOND_SPECTROGRAM_One.size)
axis[2].plot(SECOND_SPECTROGRAM_One,c="r")

Positions_One = Reading_One[0][0]
SPECTROGRAM_One = Reading_One[0][1]
SPECTROGRAM_Two = Reading_One[0][2]

figure,axis = plt.subplots(1,3,figsize=(18,7))

axis[0].set_title("CADENCE ONE")
axis[0].set_xlabel(CAD_One.shape)
axis[0].set_ylabel(CAD_One.size)
axis[0].plot(CAD_One,c="r")

axis[1].set_title("CADENCE TWO")
axis[1].set_xlabel(CAD_Two.shape)
axis[1].set_ylabel(CAD_Two.size)
axis[1].plot(CAD_Two,c="g")

axis[2].set_title("CADENCE THREE")
axis[2].set_xlabel(CAD_Three.shape)
axis[2].set_ylabel(CAD_Three.size)
axis[2].plot(CAD_Three,c="b")

# %%
One_IMG_CAD = Reading_One[0][:256].astype("float")
Two_IMG_CAD = Reading_Two[0][:256].astype("float")
Three_IMG_CAD = Reading_Three[0][:256].astype("float")

One_IMG_SPEC_1 = Reading_One[1][:256].astype("float")
Two_IMG_SPEC_1 = Reading_Two[1][:256].astype("float")
Three_IMG_SPEC_1 = Reading_Three[1][:256].astype("float")

One_IMG_SPEC_2 = Reading_One[2][:256].astype("float")
Two_IMG_SPEC_2 = Reading_Two[2][:256].astype("float")
Three_IMG_SPEC_2 = Reading_Three[2][:256].astype("float")

figure,axis = plt.subplots(4,3,figsize=(30, 30))

axis[0][0].set_title("One_IMG_CAD")
axis[0][0].set_xlabel(One_IMG_CAD.shape)
axis[0][0].set_ylabel(One_IMG_CAD.size)
axis[0][0].plot(One_IMG_CAD)

axis[0][1].set_title("One_IMG_SPEC_1")
axis[0][1].set_xlabel(One_IMG_SPEC_1.shape)
axis[0][1].set_ylabel(One_IMG_SPEC_1.size)
axis[0][1].plot(One_IMG_SPEC_1)

axis[0][2].set_title("One_IMG_SPEC_2")
axis[0][2].set_xlabel(One_IMG_SPEC_2.shape)
axis[0][2].set_ylabel(One_IMG_SPEC_2.size)
axis[0][2].plot(One_IMG_SPEC_2)

axis[1][0].set_title("One_IMG_CAD")
axis[1][0].set_xlabel(One_IMG_CAD.shape)
axis[1][0].set_ylabel(One_IMG_CAD.size)
im = axis[1][0].imshow(One_IMG_CAD)
plt.colorbar(im, ax=axis[1][0])

axis[1][1].set_title("One_IMG_SPEC_1")
axis[1][1].set_xlabel(One_IMG_SPEC_1.shape)
axis[1][1].set_ylabel(One_IMG_SPEC_1.size)
axis[1][1].imshow(One_IMG_SPEC_1)
plt.colorbar(im, ax=axis[1][1])

axis[1][2].set_title("One_IMG_SPEC_2")
axis[1][2].set_xlabel(One_IMG_SPEC_2.shape)
axis[1][2].set_ylabel(One_IMG_SPEC_2.size)
axis[1][2].imshow(One_IMG_SPEC_2)
plt.colorbar(im, ax=axis[1][2])

axis[2][0].set_title("One_IMG_CAD")
axis[2][0].set_xlabel(One_IMG_CAD.shape)
axis[2][0].set_ylabel(One_IMG_CAD.size)
axis[2][0].plot(One_IMG_CAD)

axis[2][1].set_title("Two_IMG_CAD")
axis[2][1].set_xlabel(Two_IMG_CAD.shape)
axis[2][1].set_ylabel(Two_IMG_CAD.size)
axis[2][1].plot(Two_IMG_CAD)

axis[2][2].set_title("Three_IMG_CAD")
axis[2][2].set_xlabel(Three_IMG_CAD.shape)
axis[2][2].set_ylabel(Three_IMG_CAD.size)
axis[2][2].plot(Three_IMG_CAD)

axis[3][0].set_title("One_IMG_CAD")
axis[3][0].set_xlabel(One_IMG_CAD.shape)
axis[3][0].set_ylabel(One_IMG_CAD.size)
axis[3][0].imshow(One_IMG_CAD)
plt.colorbar(im, ax=axis[3][0])

axis[3][1].set_title("Two_IMG_CAD")
axis[3][1].set_xlabel(Two_IMG_CAD.shape)
axis[3][1].set_ylabel(Two_IMG_CAD.size)
axis[3][1].imshow(Two_IMG_CAD)
plt.colorbar(im, ax=axis[3][1])

axis[3][2].set_title("Three_IMG_CAD")
axis[3][2].set_xlabel(Three_IMG_CAD.shape)
axis[3][2].set_ylabel(Three_IMG_CAD.size)
axis[3][2].imshow(Three_IMG_CAD)
plt.colorbar(im, ax=axis[3][2])

# %%
figure = plt.figure(figsize=(18,12))
for i in range(6):

    plt.subplot(6, 1, i + 1)
    plt.imshow(Reading_One[i].astype(float), interpolation='nearest', aspect='auto')
    plt.text(5, 100, ["ON", "OFF"][i % 2], bbox={'facecolor': 'green'})
    plt.colorbar()

plt.show()

figure = plt.figure(figsize=(18,12))
for i in range(6):

    plt.subplot(6, 1, i + 1)
    plt.imshow(Reading_Two[i].astype(float), interpolation='nearest', aspect='auto')
    plt.text(5, 100, ["ON", "OFF"][i % 2], bbox={'facecolor': 'green'})
    plt.colorbar()

plt.show()

figure = plt.figure(figsize=(18,12))
for i in range(6):

    plt.subplot(6, 1, i + 1)
    plt.imshow(Reading_Three[i].astype(float), interpolation='nearest', aspect='auto')
    plt.text(5, 100, ["ON", "OFF"][i % 2], bbox={'facecolor': 'green'})
    plt.colorbar()

plt.show()
